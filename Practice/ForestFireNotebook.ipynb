# %%
from ForestModel import *
import matplotlib.pyplot as plt
model = ForestModel(500, 50, 50)

for i in range(15):
    model.step()
data = model.datacollector.get_model_vars_dataframe()
data["Burned"]
plt.plot(data)
plt.xticks([i for i in range(15) if i%2==0])
plt.legend(["Fine", "On Fire", "Burned"])
plt.show()

# %%
plt.plot(data)
plt.xticks([i for i in range(15) if i%2==0])
plt.legend(["Susceptible", "Infectious", "Removed"])
plt.show()
