# %%
from RandomWalkContinuous import *
import matplotlib.pyplot as plt
import numpy as np
sim = WorldModel(1, 100, 100, np.pi/3)

# %%
sim.schedule.agents[0].pos
for i in range(100):
    sim.step()

# %%
data = sim.data_collector.get_agent_vars_dataframe()

# %%
x,y = [],[]
for i in data["Position"]:
    x.append(i[0])
    y.append(i[1])
finalx, finaly = x[-1], y[-1]
plt.plot(x,y)
plt.scatter(finalx, finaly, c="r", marker="x")
plt.grid(True, linewidth=1)
plt.xlim(0,100)
plt.ylim(0,100)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Position Over 100 Steps")
plt.savefig("Position", dpi=200)
